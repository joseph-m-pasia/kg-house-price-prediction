# %% [markdown]
# ### Import packages

# %%
from pkg_house_prices.utils.config import CONFIG
from pkg_house_prices.data.data_loader import load_data

# %% [markdown]
# ### Load the data

# %%
# Test loading data
train_df, test_df = load_data(CONFIG)
print("Train DataFrame shape:", train_df.shape)
print("Test DataFrame shape:", test_df.shape)

# %% [markdown]
# ### Understand the data types

# %%
# return the data types of the loaded dataframes for verification
print("Train DataFrame dtypes:\n", train_df.dtypes)
print("Test DataFrame dtypes:\n", test_df.dtypes)
